# %% [markdown]
# <a href="https://colab.research.google.com/github/farhanwadia/MIE1624/blob/master/Course%20Presentation/presentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/farhanwadia/MIE1624.git
# Out:
# Cloning into 'MIE1624'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 10 (delta 0), reused 4 (delta 0), pack-reused 0
# Unpacking objects: 100% (10/10), 58.88 KiB | 494.00 KiB/s, done.

# %%
# %cd MIE1624
# %cd 'Course Presentation'
# Out:
# /content/MIE1624
# /content/MIE1624/Course Presentation

# %%
# !ls
# Out:
# 'In-class presentation assignment - Group 14.pdf'   presentation.ipynb

# %%
# !pip install feedparser
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting feedparser
#   Downloading feedparser-6.0.10-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 KB 2.2 MB/s eta 0:00:00
# Collecting sgmllib3k
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6066 sha256=94d6d9efbc62ce62a7870c199126954864089d4a2d705e12fd525e34d62764a8
#   Stored in directory: /root/.cache/pip/wheels/83/63/2f/117884c3b19d46b64d3d61690333aa80c88dc14050e269c546
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser
# Successfully installed feedparser-6.0.10 sgmllib3k-1.0.0

# %% [markdown]
# A list of all RSS feeds from the New York Times can be accessed at https://www.nytimes.com/rss.
#
# Let's use the World feed from https://rss.nytimes.com/services/xml/rss/nyt/World.xml

# %%
import feedparser

d = feedparser.parse('https://rss.nytimes.com/services/xml/rss/nyt/World.xml')

d
# Out:
# {'bozo': False,
#  'entries': [{'title': 'Biden Dispatches Yellen and Blinken to Bolster Support for Ukraine',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'Biden Dispatches Yellen and Blinken to Bolster Support for Ukraine'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2023/02/27/world/europe/ukraine-yellen-blinken-russia.html'},
#     {'href': 'https://www.nytimes.com/2023/02/27/world/europe/ukraine-yellen-blinken-russia.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2023/02/27/world/europe/ukraine-yellen-blinken-russia.html',
#    'id': 'https://www.nytimes.com/2023/02/27/world/europe/ukraine-yellen-blinken-russia.html',
#    'guidislink': False,
#    'summary': 'Treasury Secretary Janet Yellen traveled to Kyiv the day before Secretary of State Antony Blinken was to visit Central Asia in a show of American solidarity with Ukraine in its battle with Russia.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'Treasury Secretary Janet Yellen traveled to Kyiv the day before Secretary of State Antony Blinken was to visit Central Asia in a show of American solidarity with Ukraine in its battle with Russia.'},
#    'authors': [{'name': 'Marc Santora and Alan Rappeport'}],
#    'author': 'Marc Santora and Alan Rappeport',
#    'author_detail': {'name': 'Marc Santora and Alan Rappeport'},
#    'published': 'Mon, 27 Feb 2023 23:07:03 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=2, tm_mday=27, tm_hour=23, tm_min=7, tm_sec=3, tm_wday=0, tm_yday=58, tm_isdst=0),
#    'tags': [{'term': 'Russian Invasion of Ukraine (2022)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Economic Conditions and Trends',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Yellen, Janet L',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'United States International Relations',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Politics and Government',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Foreign Aid',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Embargoes and Sanctions',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Defense and Military Forces',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Ukraine',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Russia',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Blinken, Antony J',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Biden, Joseph R Jr',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None}],
#    'media_content': [{'height': '151',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/02/27/multimedia/27ukraine-ledeall-mbqj/27ukraine-ledeall-mbqj-moth.jpg',
#      'width': '151'}],
#    'media_credit': [{'content': 'Thibault Camus/Associated Press'}],
#    'credit': 'Thibault Camus/Associated Press',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#      'value': 'Treasury Secretary Janet L. Yellen and Bridget Brink, the U.S. ambassador to Ukraine, placed flowers at the memorial wall of St. Michael’s Golden-Domed Cathedral in Kyiv, Ukraine, on Monday.'}]},
#   {'title': 'To Heal Brexit Wound, U.K. and E.U. Strike a Northern Ireland Trade Deal',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'To Heal Brexit Wound, U.K. and E.U. Strike a Northern Ireland Trade Deal'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2023/02/27/world/europe/uk-eu-northern-ireland.html'},
#     {'href': 'https://www.nytimes.com/2023/02/27/world/europe/uk-eu-northern-ireland.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2023/02/27/world/europe/uk-eu-northern-ireland.html',
#    'id': 'https://www.nytimes.com/2023/02/27/world/europe/uk-eu-northern-ireland.html',
#    'guidislink': False,
#    'summary': 'A dispute left over from the Britain-European Union split has chilled relations, paralyzed Northern Ireland’s government, risked a trade war and even caused friction between London and Washington.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'A dispute left over from the Britain-European Union split has chilled relations, paralyzed Northern Ireland’s government, risked a trade war and even caused friction between London and Washington.'},
#    'authors': [{'name': 'Mark Landler and Stephen Castle'}],
#    'author': 'Mark Landler and Stephen Castle',
#    'author_detail': {'name': 'Mark Landler and Stephen Castle'},
#    'published': 'Mon, 27 Feb 2023 23:08:56 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=2, tm_mday=27, tm_hour=23, tm_min=8, tm_sec=56, tm_wday=0, tm_yday=58, tm_isdst=0),
#    'tags': [{'term': 'Great Britain Withdrawal from EU (Brexit)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'International Relations',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Conservative Party (Great Britain)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'European Union',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'European Commission',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Democratic Unionist Party (Northern Ireland)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'European Court of Justice',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Sunak, Rishi (1980- )',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'von der Leyen, Ursula',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Charles III, King of the United Kingdom',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Johnson, Boris',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Biden, Joseph R Jr',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Great Britain',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Northern Ireland',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Ireland',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None}],
#    'media_content': [{'height': '151',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/02/27/multimedia/27UK-LEDEALL-hvtz/27UK-LEDEALL-hvtz-moth.jpg',
#      'width': '151'}],
#    'media_credit': [{'content': 'Pool photo by Dan Kitwood'}],
#    'credit': 'Pool photo by Dan Kitwood',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#      'value': 'Britain’s prime minister, Rishi Sunak, and Ursula von der Leyen, the president of the European Commission, announced the deal, which they called the “Windsor Framework,” on Monday.'}]},
#   {'title': 'Revenge Attacks After Killing of Israeli Settlers Leave West Bank in Turmoil',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'Revenge Attacks After Killing of Israeli Settlers Leave West Bank in Turmoil'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2023/02/27/world/middleeast/israel-palestinians-west-bank.html'},
#     {'href': 'https://www.nytimes.com/2023/02/27/world/middleeast/israel-palestinians-west-bank.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2023/02/27/world/middleeast/israel-palestinians-west-bank.html',
#    'id': 'https://www.nytimes.com/2023/02/27/world/middleeast/israel-palestinians-west-bank.html',
#    'guidislink': False,
#    'summary': 'Settlers burned and vandalized hundreds of cars and homes in four Palestinian villages, according to Israeli rights groups and Palestinian officials, and the area braced for more violence.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'Settlers burned and vandalized hundreds of cars and homes in four Palestinian villages, according to Israeli rights groups and Palestinian officials, and the area braced for more violence.'},
#    'authors': [{'name': 'Patrick Kingsley and Isabel Kershner'}],
#    'author': 'Patrick Kingsley and Isabel Kershner',
#    'author_detail': {'name': 'Patrick Kingsley and Isabel Kershner'},
#    'published': 'Mon, 27 Feb 2023 21:43:48 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=2, tm_mday=27, tm_hour=21, tm_min=43, tm_sec=48, tm_wday=0, tm_yday=58, tm_isdst=0),
#    'tags': [{'term': 'Palestinians',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Terrorism',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Israeli Settlements',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Defense and Military Forces',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Netanyahu, Benjamin',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'West Bank',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Israel',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None}],
#    'media_content': [{'height': '151',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/02/27/multimedia/27israel-01-qbkp/27israel-01-qbkp-moth.jpg',
#      'width': '151'}],
#    'media_credit': [{'content': 'Ronaldo Schemidt/Agence France-Presse — Getty Images'}],
#    'credit': 'Ronaldo Schemidt/Agence France-Presse — Getty Images',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#      'value': 'Damaged buildings and gutted vehicles on Monday after Jewish settlers set fire overnight to a scrapyard in the Palestinian town of Huwara, south of the West Bank city of Nablus.'}]},
#   {'title': 'Dying Children and Frozen Flocks in Afghanistan’s Bitter Winter of Crisis',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'Dying Children and Frozen Flocks in Afghanistan’s Bitter Winter of Crisis'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2023/02/27/world/asia/afghanistan-cold-malnutrition-crisis.html'},
#     {'href': 'https://www.nytimes.com/2023/02/27/world/asia/afghanistan-cold-malnutrition-crisis.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2023/02/27/world/asia/afghanistan-cold-malnutrition-crisis.html',
#    'id': 'https://www.nytimes.com/2023/02/27/world/asia/afghanistan-cold-malnutrition-crisis.html',
#    'guidislink': False,
#    'summary': 'Hundreds have died in plunging temperatures, and malnutrition has been rampant as the Taliban government’s ban on female workers has hampered international aid.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'Hundreds have died in plunging temperatures, and malnutrition has been rampant as the Taliban government’s ban on female workers has hampered international aid.'},
#    'authors': [{'name': 'Christina Goldbaum, Yaqoob Akbary and Kiana Hayeri'}],
#    'author': 'Christina Goldbaum, Yaqoob Akbary and Kiana Hayeri',
#    'author_detail': {'name': 'Christina Goldbaum, Yaqoob Akbary and Kiana Hayeri'},
#    'published': 'Mon, 27 Feb 2023 12:57:17 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=2, tm_mday=27, tm_hour=12, tm_min=57, tm_sec=17, tm_wday=0, tm_yday=58, tm_isdst=0),
#    'tags': [{'term': 'Afghanistan',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Famine',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Taliban',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Humanitarian Aid',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Women and Girls',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Discrimination',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Economic Conditions and Trends',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Cold and Cold Spells',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Livestock',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'vis-photo',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None}],
#    'media_content': [{'height': '151',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/02/24/multimedia/00afghanistan-crisis-promo/00afghanistan-crisis-promo-moth.jpg',
#      'width': '151'}],
#    'media_credit': [{'content': 'Kiana Hayeri for The New York Times'}],
#    'credit': 'Kiana Hayeri for The New York Times'},
#   {'title': 'Russia’s New Offensive Sends Conscripts Into the Teeth of Ukraine’s Lines',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'Russia’s New Offensive Sends Conscripts Into the Teeth of Ukraine’s Lines'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2023/02/27/world/europe/russia-offensive-ukraine.html'},
#     {'href': 'https://www.nytimes.com/2023/02/27/world/europe/russia-offensive-ukraine.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2023/02/27/world/europe/russia-offensive-ukraine.html',
#    'id': 'https://www.nytimes.com/2023/02/27/world/europe/russia-offensive-ukraine.html',
#    'guidislink': False,
#    'summary': 'A month into the campaign, Russian forces have barely budged despite forays by small units in fields, pine forests and ruined towns.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'A month into the campaign, Russian forces have barely budged despite forays by small units in fields, pine forests and ruined towns.'},
#    'authors': [{'name': 'Andrew E. Kramer and Tyler Hicks'}],
#    'author': 'Andrew E. Kramer and Tyler Hicks',
#    'author_detail': {'name': 'Andrew E. Kramer and Tyler Hicks'},
#    'published': 'Mon, 27 Feb 2023 17:28:30 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=2, tm_mday=27, tm_hour=17, tm_min=28, tm_sec=30, tm_wday=0, tm_yday=58, tm_isdst=0),
#    'tags': [{'term': 'Defense and Military Forces',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Russian Invasion of Ukraine (2022)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Draft and Recruitment (Military)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Donbas (Ukraine)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Bakhmut (Ukraine)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Lyman (Ukraine)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Ukraine',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Russia',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Putin, Vladimir V',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Budanov, Kyrylo',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Zelensky, Volodymyr',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None}],
#    'media_content': [{'height': '151',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/02/27/multimedia/27russia-offensive-1-chtk-copy/27ukraine-offensive-1-chtk-moth.jpg',
#      'width': '151'}],
#    'media_credit': [{'content': 'Tyler Hicks/The New York Times'}],
#    'credit': 'Tyler Hicks/The New York Times',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#      'value': 'Ukrainian soldiers last week on the front line in eastern Ukraine.'}]},
#   {'title': 'What Is the Northern Ireland Protocol? The Brexit Deal Changes, Explained',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'What Is the Northern Ireland Protocol? The Brexit Deal Changes, Explained'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/article/northern-ireland-protocol-brexit.html'},
#     {'href': 'https://www.nytimes.com/article/northern-ireland-protocol-brexit.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/article/northern-ireland-protocol-brexit.html',
#    'id': 'https://www.nytimes.com/article/northern-ireland-protocol-brexit.html',
#    'guidislink': False,
#    'summary': 'Britain and the European Union have long clashed over post-Brexit rules known as the Northern Ireland protocol. Here’s what to know about the renegotiated agreement.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'Britain and the European Union have long clashed over post-Brexit rules known as the Northern Ireland protocol. Here’s what to know about the renegotiated agreement.'},
#    'authors': [{'name': 'Stephen Castle and Megan Specia'}],
#    'author': 'Stephen Castle and Megan Specia',
#    'author_detail': {'name': 'Stephen Castle and Megan Specia'},
#    'published': 'Mon, 27 Feb 2023 20:21:48 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=2, tm_mday=27, tm_hour=20, tm_min=21, tm_sec=48, tm_wday=0, tm_yday=58, tm_isdst=0),
#    'tags': [{'term': 'Politics and Government',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Great Britain Withdrawal from EU (Brexit)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'International Trade and World Market',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Great Britain',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Northern Ireland',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Europe',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None}],
#    'media_content': [{'height': '151',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/03/13/multimedia/13uk-brexit-explainer-top-jghc/13uk-brexit-explainer-top-jghc-moth-v2.jpg',
#      'width': '151'}],
#    'media_credit': [{'content': 'Andrew Testa for The New York Times'}],
#    'credit': 'Andrew Testa for The New York Times',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#      'value': 'Carlingford Lough, with Northern Ireland on the left and Ireland on the right. The inlet marks the border.'}]},
#   {'title': 'Ukraine News: Yellen Visits Kyiv, Reaffirming U.S. Support',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'Ukraine News: Yellen Visits Kyiv, Reaffirming U.S. Support'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/live/2023/02/27/world/russia-ukraine-news'},
#     {'href': 'https://www.nytimes.com/live/2023/02/27/world/russia-ukraine-news',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/live/2023/02/27/world/russia-ukraine-news',
#    'id': 'https://www.nytimes.com/live/2023/02/27/world/russia-ukraine-news',
#    'guidislink': False,
#    'summary': 'Treasury Secretary Janet Yellen made an unannounced visit to the capital of Ukraine, which has used billions in aid from the United States to keep operating over the past year.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'Treasury Secretary Janet Yellen made an unannounced visit to the capital of Ukraine, which has used billions in aid from the United States to keep operating over the past year.'},
#    'authors': [{'name': 'The New York Times'}],
#    'author': 'The New York Times',
#    'author_detail': {'name': 'The New York Times'},
#    'published': 'Tue, 28 Feb 2023 00:30:52 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=2, tm_mday=28, tm_hour=0, tm_min=30, tm_sec=52, tm_wday=1, tm_yday=59, tm_isdst=0),
#    'media_content': [{'height': '151',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/02/27/multimedia/27ukraine-blog-Section-front-bqvl/27ukraine-blog-Section-front-bqvl-moth.jpg',
#      'width': '151'}],
#    'media_credit': [{'content': 'Gleb Garanich/Reuters'}],
#    'credit': 'Gleb Garanich/Reuters'},
#   {'title': 'Britain and E.U. Agree on Northern Ireland Trade Deal',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'Britain and E.U. Agree on Northern Ireland Trade Deal'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/live/2023/02/27/world/northern-ireland-brexit-trade-deal'},
#     {'href': 'https://www.nytimes.com/live/2023/02/27/world/northern-ireland-brexit-trade-deal',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/live/2023/02/27/world/northern-ireland-brexit-trade-deal',
#    'id': 'https://www.nytimes.com/live/2023/02/27/world/northern-ireland-brexit-trade-deal',
#    'guidislink': False,
#    'summary': 'The agreement may resolve one of the most poisonous legacies of Brexit, Britain’s fraught exit from the European Union.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'The agreement may resolve one of the most poisonous legacies of Brexit, Britain’s fraught exit from the European Union.'},
#    'authors': [{'name': 'The New York Times'}],
#    'author': 'The New York Times',
#    'author_detail': {'name': 'The New York Times'},
#    'published': 'Mon, 27 Feb 2023 23:41:11 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=2, tm_mday=27, tm_hour=23, tm_min=41, tm_sec=11, tm_wday=0, tm_yday=58, tm_isdst=0),
#    'media_content': [{'height': '151',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/02/27/multimedia/HFO-uk-protocol-vonderleyen-jckq/HFO-uk-protocol-vonderleyen-jckq-moth-v2.jpg',
#      'width': '151'}],
#    'media_credit': [{'content': 'Dan Kitwood/Agence France-Presse — Getty Images'}],
#    'credit': 'Dan Kitwood/Agence France-Presse — Getty Images',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#      'value': 'Ursula von der Leyen, president of the European Commission, and Prime Minister Rishi Sunak of Britain meet in Windsor, England, on Monday.'}]},
#   {'title': 'Migrant Deaths Shine Light on Europe’s Broken Promises',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'Migrant Deaths Shine Light on Europe’s Broken Promises'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2023/02/27/world/europe/italy-migrants-shipwreck-europe.html'},
#     {'href': 'https://www.nytimes.com/2023/02/27/world/europe/italy-migrants-shipwreck-europe.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2023/02/27/world/europe/italy-migrants-shipwreck-europe.html',
#    'id': 'https://www.nytimes.com/2023/02/27/world/europe/italy-migrants-shipwreck-europe.html',
#    'guidislink': False,
#    'summary': 'At least 63 people died in a shipwreck off Italy’s coast, reviving memories of a crash in 2013 that killed hundreds and the work that did not get done in its aftermath.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'At least 63 people died in a shipwreck off Italy’s coast, reviving memories of a crash in 2013 that killed hundreds and the work that did not get done in its aftermath.'},
#    'authors': [{'name': 'Jason Horowitz and Gaia Pianigiani'}],
#    'author': 'Jason Horowitz and Gaia Pianigiani',
#    'author_detail': {'name': 'Jason Horowitz and Gaia Pianigiani'},
#    'published': 'Mon, 27 Feb 2023 21:23:39 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=2, tm_mday=27, tm_hour=21, tm_min=23, tm_sec=39, tm_wday=0, tm_yday=58, tm_isdst=0),
#    'tags': [{'term': 'Deaths (Fatalities)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'International Relations',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Politics and Government',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Border Barriers',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Middle East and Africa Migrant Crisis',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Rescues',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Illegal Immigration',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Humanitarian Aid',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Drownings',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Coastal Areas',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Meloni, Giorgia (1977- )',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Italy',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Europe',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None}],
#    'media_content': [{'height': '151',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/02/27/multimedia/27italy-migrants-01-wgkt/27italy-migrants-01-wgkt-moth.jpg',
#      'width': '151'}],
#    'media_credit': [{'content': 'Giovanni Isolino/LaPresse, via Associated Press'}],
#    'credit': 'Giovanni Isolino/LaPresse, via Associated Press',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#      'value': 'A memorial for the shipwreck’s victims near Cutro, Italy, on Monday.'}]},
#   {'title': 'A New 5.2-Magnitude Earthquake Strikes Turkey',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'A New 5.2-Magnitude Earthquake Strikes Turkey'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2023/02/27/world/middleeast/turkey-earthquake.html'},
#     {'href': 'https://www.nytimes.com/2023/02/27/world/middleeast/turkey-earthquake.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2023/02/27/world/middleeast/turkey-earthquake.html',
#    'id': 'https://www.nytimes.com/2023/02/27/world/middleeast/turkey-earthquake.html',
#    'guidislink': False,
#    'summary': 'The latest temblor, measuring 5.2 in magnitude, shook parts of the same area stricken by a far stronger quake on Feb. 6 that killed more than 50,000 people in the country and in neighboring Syria.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'The latest temblor, measuring 5.2 in magnitude, shook parts of the same area stricken by a far stronger quake on Feb. 6 that killed more than 50,000 people in the country and in neighboring Syria.'},
#    'authors': [{'name': 'Ben Hubbard and Gulsin Harman'}],
#    'author': 'Ben Hubbard and Gulsin Harman',
#    'author_detail': {'name': 'Ben Hubbard and Gulsin Harman'},
#    'published': 'Mon, 27 Feb 2023 22:10:50 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=2, tm_mday=27, tm_hour=22, tm_min=10, tm_sec=50, tm_wday=0, tm_yday=58, tm_isdst=0),
#    'tags': [{'term': 'Earthquakes',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Turkey Earthquake (Feb 6, 2023)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Accidents and Safety',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Buildings (Structures)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Deaths (Fatalities)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Assad, Bashar al-',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Erdogan, Recep Tayyip',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Kahramanmaras (Turkey)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Syria',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Turkey',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None}],
#    'media_content': [{'height': '151',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/02/27/multimedia/27turkey-htkq/27turkey-htkq-moth-v2.jpg',
#      'width': '151'}],
#    'media_credit': [{'content': 'Demiroren News Agency, via Agence France-Presse — Getty Images'}],
#    'credit': 'Demiroren News Agency, via Agence France-Presse — Getty Images',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#      'value': 'Rescuers searched the rubble of a collapsed building in Yesilyurt, near Malatya, Turkey, on Monday, after a new earthquake hit the area.'}]},
#   {'title': 'Manish Sisodia, Indian Opposition Leader, Is Arrested on Corruption Charges',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'Manish Sisodia, Indian Opposition Leader, Is Arrested on Corruption Charges'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2023/02/27/world/asia/india-manish-sisodia-arrest.html'},
#     {'href': 'https://www.nytimes.com/2023/02/27/world/asia/india-manish-sisodia-arrest.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2023/02/27/world/asia/india-manish-sisodia-arrest.html',
#    'id': 'https://www.nytimes.com/2023/02/27/world/asia/india-manish-sisodia-arrest.html',
#    'guidislink': False,
#    'summary': 'The detention follows a bitter fight between India’s B.J.P. governing party and a regional competitor with national ambitions.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'The detention follows a bitter fight between India’s B.J.P. governing party and a regional competitor with national ambitions.'},
#    'authors': [{'name': 'Sameer Yasir'}],
#    'author': 'Sameer Yasir',
#    'author_detail': {'name': 'Sameer Yasir'},
#    'published': 'Mon, 27 Feb 2023 14:42:08 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=2, tm_mday=27, tm_hour=14, tm_min=42, tm_sec=8, tm_wday=0, tm_yday=58, tm_isdst=0),
#    'tags': [{'term': 'Demonstrations, Protests and Riots',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Legislatures and Parliaments',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Aam Aadmi Party (India)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Central Bureau of Investigation (India)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Kejriwal, Arvind',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Modi, Narendra',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Sisodia, Manish',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'India',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None}],
#    'media_content': [{'height': '151',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/02/27/multimedia/27india-politics-01-cvlt/27india-politics-01-cvlt-moth-v3.jpg',
#      'width': '151'}],
#    'media_credit': [{'content': 'Saumya Khandelwal for The New York Times'}],
#    'credit': 'Saumya Khandelwal for The New York Times',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#      'value': 'Manish Sisodia, a top leader of the Aam Aadmi Party, shown in February 2022, was arrested Sunday on accusations of corruption in a liquor policy change.'}]},
#   {'title': 'Northern Lights Seen Across the U.K. in Rare Show',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'Northern Lights Seen Across the U.K. in Rare Show'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2023/02/27/world/europe/northern-lights-uk.html'},
#     {'href': 'https://www.nytimes.com/2023/02/27/world/europe/northern-lights-uk.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2023/02/27/world/europe/northern-lights-uk.html',
#    'id': 'https://www.nytimes.com/2023/02/27/world/europe/northern-lights-uk.html',
#    'guidislink': False,
#    'summary': 'The sight, which usually involves a trip to a snowy outpost, could be seen in the south of England.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'The sight, which usually involves a trip to a snowy outpost, could be seen in the south of England.'},
#    'authors': [{'name': 'Emma Bubola'}],
#    'author': 'Emma Bubola',
#    'author_detail': {'name': 'Emma Bubola'},
#    'published': 'Mon, 27 Feb 2023 15:53:49 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=2, tm_mday=27, tm_hour=15, tm_min=53, tm_sec=49, tm_wday=0, tm_yday=58, tm_isdst=0),
#    'tags': [{'term': 'Earth',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Aurora Borealis',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Space and Astronomy',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Weather',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'National Weather Service',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Met Office (United Kingdom)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'European Space Agency',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Cornwall (England)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Europe',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'England',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Great Britain',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Scotland',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None}],
#    'media_content': [{'height': '151',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/02/27/world/27northern-lights2/27northern-lights2-moth-v2.jpg',
#      'width': '151'}],
#    'media_credit': [{'content': 'Reiss McGuire/Alamy'}],
#    'credit': 'Reiss McGuire/Alamy',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#      'value': 'The northern lights over the Trossachs in Scotland on Sunday.'}]},
#   {'title': 'In Central Asia, Blinken Will Urge Distance From Russia, and Ukraine War',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'In Central Asia, Blinken Will Urge Distance From Russia, and Ukraine War'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2023/02/27/world/asia/blinken-china-russia-ukraine-war.html'},
#     {'href': 'https://www.nytimes.com/2023/02/27/world/asia/blinken-china-russia-ukraine-war.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2023/02/27/world/asia/blinken-china-russia-ukraine-war.html',
#    'id': 'https://www.nytimes.com/2023/02/27/world/asia/blinken-china-russia-ukraine-war.html',
#    'guidislink': False,
#    'summary': 'Secretary of State Antony J. Blinken is making the first trip by a Biden administration cabinet official to the former Soviet republics of Central Asia.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'Secretary of State Antony J. Blinken is making the first trip by a Biden administration cabinet official to the former Soviet republics of Central Asia.'},
#    'authors': [{'name': 'Edward Wong, Anton Troianovski and Stanley Reed'}],
#    'author': 'Edward Wong, Anton Troianovski and Stanley Reed',
#    'author_detail': {'name': 'Edward Wong, Anton Troianovski and Stanley Reed'},
#    'published': 'Tue, 28 Feb 2023 00:30:48 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=2, tm_mday=28, tm_hour=0, tm_min=30, tm_sec=48, tm_wday=1, tm_yday=59, tm_isdst=0),
#    'tags': [{'term': 'Russian Invasion of Ukraine (2022)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'United States International Relations',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Politics and Government',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'International Relations',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Blinken, Antony J',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Ukraine',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Russia',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'China',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Kazakhstan',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Uzbekistan',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Kyrgyzstan',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Turkmenistan',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Tajikistan',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Putin, Vladimir V',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Biden, Joseph R Jr',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'United States',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Xi Jinping',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None}],
#    'media_content': [{'height': '151',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/02/27/multimedia/27kazakhstan-blinken-01-bhjl/27kazakhstan-blinken-01-bhjl-moth.jpg',
#      'width': '151'}],
#    'media_credit': [{'content': 'Kevin Lamarque/Reuters'}],
#    'credit': 'Kevin Lamarque/Reuters',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#      'value': 'Antony J. Blinken, the U.S. secretary of state, will meet with foreign ministers from five Central Asian republics.'}]},
#   {'title': 'Their Hair Long and Flowing or in Ponytails, Women in Iran Flaunt Their Locks',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'Their Hair Long and Flowing or in Ponytails, Women in Iran Flaunt Their Locks'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2023/02/25/world/middleeast/iran-women-hijab-hair.html'},
#     {'href': 'https://www.nytimes.com/2023/02/25/world/middleeast/iran-women-hijab-hair.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2023/02/25/world/middleeast/iran-women-hijab-hair.html',
#    'id': 'https://www.nytimes.com/2023/02/25/world/middleeast/iran-women-hijab-hair.html',
#    'guidislink': False,
#    'summary': 'Defiant resistance to Iran’s mandatory hijab law has exploded across the country after nationwide protests that erupted last year.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'Defiant resistance to Iran’s mandatory hijab law has exploded across the country after nationwide protests that erupted last year.'},
#    'authors': [{'name': 'Farnaz Fassihi'}],
#    'author': 'Farnaz Fassihi',
#    'author_detail': {'name': 'Farnaz Fassihi'},
#    'published': 'Sat, 25 Feb 2023 22:17:55 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=2, tm_mday=25, tm_hour=22, tm_min=17, tm_sec=55, tm_wday=5, tm_yday=56, tm_isdst=0),
#    'tags': [{'term': 'Iran',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Muslim Veiling',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Demonstrations, Protests and Riots',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Women and Girls',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': "Women's Rights",
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Muslims and Islam',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Amini, Mahsa (2000-22)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Raisi, Ebrahim',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Politics and Government',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None}],
#    'media_content': [{'height': '151',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/02/25/world/25iran-hijab/25iran-hijab-moth-v2.jpg',
#      'width': '151'}],
#    'media_credit': [{'content': 'Arash Khamooshi for The New York Times'}],
#    'credit': 'Arash Khamooshi for The New York Times',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#      'value': 'A woman, sans head covering, at the Tajrish Bazaar in Tehran last month.'}]},
#   {'title': 'Where Did Covid Originate? Here’s What We Know and Don’t Know',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'Where Did Covid Originate? Here’s What We Know and Don’t Know'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2023/02/27/us/politics/covid-origin-lab-leak-china.html'},
#     {'href': 'https://www.nytimes.com/2023/02/27/us/politics/covid-origin-lab-leak-china.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
# ...
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'Doctor Denounces C.I.A. Practice of ‘Rectal Feeding’ of Prisoners'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2023/02/24/us/politics/cia-torture-guantanamo-nashiri-doctor.html'},
#     {'href': 'https://www.nytimes.com/2023/02/24/us/politics/cia-torture-guantanamo-nashiri-doctor.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2023/02/24/us/politics/cia-torture-guantanamo-nashiri-doctor.html',
#    'id': 'https://www.nytimes.com/2023/02/24/us/politics/cia-torture-guantanamo-nashiri-doctor.html',
#    'guidislink': False,
#    'summary': 'In a hearing at Guantánamo Bay, an expert gave a graphic public depiction of torture after the Sept. 11, 2001, terror attacks.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'In a hearing at Guantánamo Bay, an expert gave a graphic public depiction of torture after the Sept. 11, 2001, terror attacks.'},
#    'authors': [{'name': 'Carol Rosenberg'}],
#    'author': 'Carol Rosenberg',
#    'author_detail': {'name': 'Carol Rosenberg'},
#    'published': 'Sat, 25 Feb 2023 14:14:24 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=2, tm_mday=25, tm_hour=14, tm_min=14, tm_sec=24, tm_wday=5, tm_yday=56, tm_isdst=0),
#    'tags': [{'term': 'Guantanamo Bay Naval Base (Cuba)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Central Intelligence Agency',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Torture',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Detainees',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Terrorism',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Nashiri, Abd al-Rahim al-',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Al Qaeda',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'September 11 (2001)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Crosby, Sondra S',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'United States Defense and Military Forces',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'United States Politics and Government',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None}],
#    'media_content': [{'height': '151',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/02/24/us/politics/24dc-gitmo/24dc-gitmo-moth.jpg',
#      'width': '151'}],
#    'media_credit': [{'content': 'Pool photo by Bob Child'}],
#    'credit': 'Pool photo by Bob Child',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#      'value': 'Dr. Sondra S. Crosby, an expert on torture and trauma, testifying in a Connecticut court in 2009. “This was a very, very distressing painful, shameful stigmatizing event,” she said of the C.I.A. torture practice.'}]},
#   {'title': '5 New(ish) Australasian Books for Your Reading List',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': '5 New(ish) Australasian Books for Your Reading List'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2023/02/24/world/australia/books-australia-new-zealand.html'},
#     {'href': 'https://www.nytimes.com/2023/02/24/world/australia/books-australia-new-zealand.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2023/02/24/world/australia/books-australia-new-zealand.html',
#    'id': 'https://www.nytimes.com/2023/02/24/world/australia/books-australia-new-zealand.html',
#    'guidislink': False,
#    'summary': 'Great reads you might have missed.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'Great reads you might have missed.'},
#    'authors': [{'name': 'Natasha Frost'}],
#    'author': 'Natasha Frost',
#    'author_detail': {'name': 'Natasha Frost'},
#    'published': 'Fri, 24 Feb 2023 07:09:34 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=2, tm_mday=24, tm_hour=7, tm_min=9, tm_sec=34, tm_wday=4, tm_yday=55, tm_isdst=0),
#    'tags': [{'term': 'Books and Literature',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Book Trade and Publishing',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Auckland (New Zealand)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Australia',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None}],
#    'media_content': [{'height': '151',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/02/24/multimedia/24-ausletter-295-1-lzcj/24-ausletter-295-1-lzcj-moth.jpg',
#      'width': '151'}],
#    'media_credit': [{'content': 'Alexi Rosenfeld/Getty Images'}],
#    'credit': 'Alexi Rosenfeld/Getty Images',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#      'value': 'Outside Readings bookstore in Carlton, Australia, this month.'}]},
#   {'title': 'Russia, Ukraine and the West Vow to Fight On, in a War With No End in Sight',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'Russia, Ukraine and the West Vow to Fight On, in a War With No End in Sight'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2023/02/24/world/europe/russia-ukraine-war-next-steps.html'},
#     {'href': 'https://www.nytimes.com/2023/02/24/world/europe/russia-ukraine-war-next-steps.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2023/02/24/world/europe/russia-ukraine-war-next-steps.html',
#    'id': 'https://www.nytimes.com/2023/02/24/world/europe/russia-ukraine-war-next-steps.html',
#    'guidislink': False,
#    'summary': 'Moscow and Kyiv face daunting challenges in moving forward, with no clear sense of what an attainable victory might look like.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'Moscow and Kyiv face daunting challenges in moving forward, with no clear sense of what an attainable victory might look like.'},
#    'authors': [{'name': 'Anton Troianovski, Steven Erlanger and Marc Santora'}],
#    'author': 'Anton Troianovski, Steven Erlanger and Marc Santora',
#    'author_detail': {'name': 'Anton Troianovski, Steven Erlanger and Marc Santora'},
#    'published': 'Fri, 24 Feb 2023 23:04:25 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=2, tm_mday=24, tm_hour=23, tm_min=4, tm_sec=25, tm_wday=4, tm_yday=55, tm_isdst=0),
#    'tags': [{'term': 'Russian Invasion of Ukraine (2022)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Defense and Military Forces',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'International Relations',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'United States International Relations',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Ukraine',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Russia',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Zelensky, Volodymyr',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Putin, Vladimir V',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Biden, Joseph R Jr',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'North Atlantic Treaty Organization',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None}],
#    'media_content': [{'height': '151',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/02/24/multimedia/24ukraine-next1/24ukraine-carousel-new-01sx-clvz-moth.jpg',
#      'width': '151'}],
#    'media_credit': [{'content': 'Emile Ducke for The New York Times'}],
#    'credit': 'Emile Ducke for The New York Times',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#      'value': 'Mourners in Bucha on Friday visiting the graves of Ukrainian soldiers who died fighting in the war.'}]},
#   {'title': '10 Years After Lac-Mégantic Tragedy, Are Canada’s Rails Safe?',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': '10 Years After Lac-Mégantic Tragedy, Are Canada’s Rails Safe?'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2023/02/24/world/americas/canada-train-derailment.html'},
#     {'href': 'https://www.nytimes.com/2023/02/24/world/americas/canada-train-derailment.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2023/02/24/world/americas/canada-train-derailment.html',
#    'id': 'https://www.nytimes.com/2023/02/24/world/americas/canada-train-derailment.html',
#    'guidislink': False,
#    'summary': 'When a runaway train loaded with oil jumped the tracks in Lac-Mégantic, Quebec, 47 people died in Canada’s worst rail disaster in nearly 150 years.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'When a runaway train loaded with oil jumped the tracks in Lac-Mégantic, Quebec, 47 people died in Canada’s worst rail disaster in nearly 150 years.'},
#    'authors': [{'name': 'Ian Austen'}],
#    'author': 'Ian Austen',
#    'author_detail': {'name': 'Ian Austen'},
#    'published': 'Mon, 27 Feb 2023 15:31:57 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=2, tm_mday=27, tm_hour=15, tm_min=31, tm_sec=57, tm_wday=0, tm_yday=58, tm_isdst=0),
#    'tags': [{'term': 'Railroads',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Railroad Accidents and Safety',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Accidents and Safety',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Montreal, Maine & Atlantic Railway',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Transport Canada',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Transportation Safety Board of Canada',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Campbell, Bruce',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Canada',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Lac-Megantic (Quebec)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Quebec Province (Canada)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None}],
#    'media_content': [{'height': '151',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/02/24/multimedia/24canada-train-01-bzjq/24canada-train-01-bzjq-moth.jpg',
#      'width': '151'}],
#    'media_credit': [{'content': 'Ian Willms for The New York Times'}],
#    'credit': 'Ian Willms for The New York Times',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#      'value': 'The site of the devastating 2013 train derailment, known locally as “the tragedy,” in Lac-Mégantic, Quebec.'}]}],
#  'feed': {'title': 'NYT > World News',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#    'value': 'NYT > World News'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://www.nytimes.com/section/world'},
#    {'href': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'rel': 'self',
#     'type': 'application/rss+xml'}],
#   'link': 'https://www.nytimes.com/section/world',
#   'subtitle': '',
#   'subtitle_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#    'value': ''},
#   'language': 'en-us',
#   'rights': 'Copyright 2023 The New York Times Company',
#   'rights_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#    'value': 'Copyright 2023 The New York Times Company'},
#   'updated': 'Tue, 28 Feb 2023 01:32:34 +0000',
#   'updated_parsed': time.struct_time(tm_year=2023, tm_mon=2, tm_mday=28, tm_hour=1, tm_min=32, tm_sec=34, tm_wday=1, tm_yday=59, tm_isdst=0),
#   'published': 'Tue, 28 Feb 2023 00:41:50 +0000',
#   'published_parsed': time.struct_time(tm_year=2023, tm_mon=2, tm_mday=28, tm_hour=0, tm_min=41, tm_sec=50, tm_wday=1, tm_yday=59, tm_isdst=0),
#   'image': {'title': 'NYT > World News',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#     'value': 'NYT > World News'},
#    'href': 'https://static01.nyt.com/images/misc/NYT_logo_rss_250x40.png',
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/section/world'}],
#    'link': 'https://www.nytimes.com/section/world'}},
#  'headers': {'connection': 'close',
#   'content-length': '22885',
#   'access-control-allow-headers': 'Accept, Content-Type, X-Forwarded-For, X-Prototype-Version, X-Requested-With',
#   'access-control-allow-methods': 'GET, OPTIONS',
#   'access-control-allow-origin': '*',
#   'access-control-expose-headers': 'Content-Length, X-JSON',
#   'content-encoding': 'gzip',
#   'x-cloud-trace-context': '2f23a5e9c2ab728dd804bb41f32157a5',
#   'server': 'Google Frontend',
#   'cache-control': 'public, max-age=300',
#   'content-type': 'application/xml',
#   'accept-ranges': 'bytes',
#   'date': 'Tue, 28 Feb 2023 01:36:46 GMT',
#   'via': '1.1 varnish',
#   'age': '252',
#   'x-served-by': 'cache-lax10661-LGB',
#   'x-cache': 'HIT',
#   'x-cache-hits': '1',
#   'x-timer': 'S1677548206.173199,VS0,VE2',
#   'vary': 'Accept-Encoding,Accept-Encoding',
#   'strict-transport-security': 'max-age=63072000; preload; includeSubdomains'},
#  'href': 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml',
#  'status': 200,
#  'encoding': 'utf-8',
#  'version': 'rss20',
#  'namespaces': {'dc': 'http://purl.org/dc/elements/1.1/',
#   'media': 'http://search.yahoo.com/mrss/',
#   '': 'http://www.w3.org/2005/Atom',
#   'nyt': 'http://www.nytimes.com/namespaces/rss/2.0'}}

# %% [markdown]
# **Extract most commonly used elements in RSS feeds such as “title”,
# “link”, “description”, “publication date”, “entry ID”, etc. Follow “links” in the RSS feed and
# extract text of news articles using web scraping in Python or other Python methods. You can use
# BeautifulSoup library in Python for pulling data out of HTML and XML files. In your IPython
# example, use a news web-site of your choice and create a Pandas dataframe from your RSS parsing
# results representing fields of metadata from that article, e.g., title, date, link, author, etc., as well
# as text of the news article. Print a table with your results and export those as a csv file with each
# row as an article and columns as article’s metadata (including full text of each article).**
